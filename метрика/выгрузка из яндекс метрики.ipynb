# %% [markdown]
# # Получение сырых данных из Яндекс Метрики

# %% [markdown]
# ### Подготовка к работе

# %% [markdown]
# **Описание таблиц**
# Документация API Metrika: https://tech.yandex.ru/metrika/doc/api2/concept/about-docpage/
# Просмотры: https://tech.yandex.ru/metrika/doc/api2/logs/fields/hits-docpage/
# Визиты:    https://tech.yandex.ru/metrika/doc/api2/logs/fields/visits-docpage/

# %% [markdown]
# # Загрузка библиотек

# %%
import requests
import json
import pandas as pd
from io import StringIO

# %% [markdown]
# # Функции

# %% [markdown]
# ## создание нового запроса

# %%
def make_post_request(source, token, counterId, dt1, dt2, col):
    url = f'https://api-metrika.yandex.net/management/v1/counter/{counterId}/logrequests'
    payload = {
    'date1': dt1,
    'date2': dt2,
    'fields': col,
    'source' : source
    }
    header = {'Authorization': f'OAuth {token}'}
    
    post = requests.post(url,data=payload, headers=header)
    # печатаем ответ, обращаем внимание на параметры:
    # request_id - id нашего запроса (нужен для скачивания информации)
    # status - показывает создан ли наш лог запросов ("status":"created")
    logs = json.loads(post.text)
    print('Cоздан запрос id: {}, со статусом: {}'.format(logs['log_request']['request_id'], logs['log_request']['status']))
    return post.text

# %% [markdown]
# ## список ранее созданных запросов

# %%
def get_all_id_requests(counterId, token):
    # получаем все id запросов на сервере
    url = f'https://api-metrika.yandex.net/management/v1/counter/{counterId}/logrequests'
    
    header = {'Authorization': f'OAuth {token}'}
    all_requests = requests.get(url, headers=header)

    
    logs = json.loads(all_requests.text)
    res = [log['request_id'] for log in logs['requests']]
    return res#, logs

# %% [markdown]
# ## удаление ранее созданных запросов

# %%
def clean_all_request(counterId, token):
    header = {'Authorization': f'OAuth {token}'}
    # удаляем все запросы на сервере
    id_list = get_all_id_requests(counterId, token)#[0]
    if not id_list:
        print('На сервере нет логов')
        return None
    for requestId in id_list:
        url = f'https://api-metrika.yandex.net/management/v1/counter/{counterId}/logrequest/{requestId}/clean'
        post = requests.post(url, headers=header)
        print(f'Запрос id {requestId} удален...')
    return None

# %% [markdown]
# ## статус запроса

# %%
def check_request_status(counterId, token, requestId):
    # проверяем доступен ли наш запрос для скачивания логов ("status":"processed")
    url = f'https://api-metrika.yandex.net/management/v1/counter/{counterId}/logrequest/{requestId}'
    header = {'Authorization': f'OAuth {token}'}
    
    all_requests = requests.get(url, headers=header)
    
    logs = json.loads(all_requests.text)
    
    status = logs['log_request']['status']
    return requestId, status

# %% [markdown]
# ## создание df

# %%
def request_to_dataframe(counterId, token, requestId, partNumber=0):
    url = f'https://api-metrika.yandex.net/management/v1/counter/{counterId}/logrequest/{requestId}/part/{partNumber}/download'
    header = {'Authorization': f'OAuth {token}'}
    r = requests.get(url, headers=header)
    df = pd.read_csv(StringIO(r.text), header=0, sep='\t')
    return df

# %%
# функция составления строки с перечнем столбцов для нового запроса
def columns(df, index_list):
    if len(index_list) >0:
        col = df.loc[0][0]
        for i in (index_list[1:]):
            col = col + ',' + df.loc[i][0]
        return col
    else:
        col = df.loc[0][0]
        for i in range(1,df.shape[0]):
            col = col + ',' + df.loc[i][0]
        return col

# %% [markdown]
# # Основной блок

# %% [markdown]
# ## Устанавливаем значения

# %%
# Устанавливаем значения для запроса:
# token     - токен для получения информации
# counterId - номер счетчика Яндекс Метрики (если несколько, указываются через запятую)

token = 
counterId =

# %% [markdown]
# ### выбор полей(столбцов)

# %%
# посмотреть список полей с описанием
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    display(x)
    pd.reset_option('display.max_rows')

# %% [markdown]
# #### visits

# %%
from io import BytesIO

spreadsheet_id = '1aW4sN9vDBnL76X9WxBhx9nt0xvq8FKlgk8B1ArGxne4'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
vis = pd.read_csv(BytesIO(r.content))

vis.columns = vis.columns.str.replace(' ','')
vis['Поле'] = vis['Поле'].str.replace(' ','')

# %%
print_full(vis)
# Out:
#                                  Поле  \
# 0                        ym:s:visitID
# 1                      ym:s:counterID
# 2                       ym:s:watchIDs
# 3                           ym:s:date
# 4                       ym:s:dateTime
# 5                    ym:s:dateTimeUTC
# 6                      ym:s:isNewUser
# 7                       ym:s:startURL
# 8                         ym:s:endURL
# 9                      ym:s:pageViews
# 10                 ym:s:visitDuration
# 11                        ym:s:bounce
# 12                     ym:s:ipAddress
# 13                 ym:s:regionCountry
# 14                    ym:s:regionCity
# 15               ym:s:regionCountryID
# 16                  ym:s:regionCityID
# 17                      ym:s:clientID
# 18                   ym:s:networkType
# 19                       ym:s:goalsID
# 20             ym:s:goalsSerialNumber
# 21                 ym:s:goalsDateTime
# 22                    ym:s:goalsPrice
# 23                    ym:s:goalsOrder
# 24                 ym:s:goalsCurrency
# 25             ym:s:lastTrafficSource
# 26                 ym:s:lastAdvEngine
# 27             ym:s:lastReferalSource
# 28          ym:s:lastSearchEngineRoot
# 29              ym:s:lastSearchEngine
# 30             ym:s:lastSocialNetwork
# 31      ym:s:lastSocialNetworkProfile
# 32                       ym:s:referer
# 33          ym:s:lastDirectClickOrder
# 34         ym:s:lastDirectBannerGroup
# 35         ym:s:lastDirectClickBanner
# 36      ym:s:lastDirectClickOrderName
# 37      ym:s:lastClickBannerGroupName
# 38     ym:s:lastDirectClickBannerName
# 39        ym:s:lastDirectPhraseOrCond
# 40        ym:s:lastDirectPlatformType
# 41            ym:s:lastDirectPlatform
# 42       ym:s:lastDirectConditionType
# 43                ym:s:lastCurrencyID
# 44                          ym:s:from
# 45                   ym:s:UTMCampaign
# 46                    ym:s:UTMContent
# 47                     ym:s:UTMMedium
# 48                     ym:s:UTMSource
# 49                       ym:s:UTMTerm
# 50                    ym:s:openstatAd
# 51              ym:s:openstatCampaign
# 52               ym:s:openstatService
# 53                ym:s:openstatSource
# 54                      ym:s:hasGCLID
# 55                     ym:s:lastGCLID
# 56                    ym:s:firstGCLID
# 57          ym:s:lastSignificantGCLID
# 58               ym:s:browserLanguage
# 59                ym:s:browserCountry
# 60                ym:s:clientTimeZone
# 61                ym:s:deviceCategory
# 62                   ym:s:mobilePhone
# 63              ym:s:mobilePhoneModel
# 64           ym:s:operatingSystemRoot
# 65               ym:s:operatingSystem
# 66                       ym:s:browser
# 67                 ym:s:browserEngine
# 68                 ym:s:cookieEnabled
# 69             ym:s:javascriptEnabled
# 70                  ym:s:screenFormat
# 71                  ym:s:screenColors
# 72             ym:s:screenOrientation
# 73                   ym:s:screenWidth
# 74                  ym:s:screenHeight
# 75           ym:s:physicalScreenWidth
# 76          ym:s:physicalScreenHeight
# 77             ym:s:windowClientWidth
# 78            ym:s:windowClientHeight
# 79                    ym:s:purchaseID
# 80              ym:s:purchaseDateTime
# 81           ym:s:purchaseAffiliation
# 82               ym:s:purchaseRevenue
# 83                   ym:s:purchaseTax
# 84              ym:s:purchaseShipping
# 85                ym:s:purchaseCoupon
# 86              ym:s:purchaseCurrency
# 87       ym:s:purchaseProductQuantity
# 88            ym:s:productsPurchaseID
# 89                    ym:s:productsID
# 90                  ym:s:productsName
# 91                 ym:s:productsBrand
# 92              ym:s:productsCategory
# 93             ym:s:productsCategory1
# 94             ym:s:productsCategory2
# 95             ym:s:productsCategory3
# 96             ym:s:productsCategory4
# 97             ym:s:productsCategory5
# 98               ym:s:productsVariant
# 99              ym:s:productsPosition
# 100                ym:s:productsPrice
# 101             ym:s:productsCurrency
# 102               ym:s:productsCoupon
# 103             ym:s:productsQuantity
# 104               ym:s:impressionsURL
# 105          ym:s:impressionsDateTime
# 106         ym:s:impressionsProductID
# 107       ym:s:impressionsProductName
# 108      ym:s:impressionsProductBrand
# 109   ym:s:impressionsProductCategory
# 110  ym:s:impressionsProductCategory1
# 111  ym:s:impressionsProductCategory2
# 112  ym:s:impressionsProductCategory3
# 113  ym:s:impressionsProductCategory4
# 114  ym:s:impressionsProductCategory5
# 115    ym:s:impressionsProductVariant
# 116      ym:s:impressionsProductPrice
# 117   ym:s:impressionsProductCurrency
# 118     ym:s:impressionsProductCoupon
# 119      ym:s:offlineCallTalkDuration
# 120      ym:s:offlineCallHoldDuration
# 121            ym:s:offlineCallMissed
# 122               ym:s:offlineCallTag
# 123   ym:s:offlineCallFirstTimeCaller
# 124               ym:s:offlineCallURL
# 125             ym:s:parsedParamsKey1
# 126             ym:s:parsedParamsKey2
# 127             ym:s:parsedParamsKey3
# 128             ym:s:parsedParamsKey4
# 129             ym:s:parsedParamsKey5
# 130             ym:s:parsedParamsKey6
# 131             ym:s:parsedParamsKey7
# 132             ym:s:parsedParamsKey8
# 133             ym:s:parsedParamsKey9
# 134            ym:s:parsedParamsKey10
#
#                                               Описание
# 0                                 Идентификатор визита
# 1                                       Номер счетчика
# 2    Просмотры, которые были в данном визите. Огран...
# 3                                          Дата визита
# 4       Дата и время визита (в часовом поясе счетчика)
# 5         Дата и время события (в часовом поясе UTC+3)
# 6                              Первый визит посетителя
# 7                                       Страница входа
# 8                                      Страница выхода
# 9                         Глубина просмотра (детально)
# 10                           Время на сайте (детально)
# 11                                          Отказность
# 12                                            IP адрес
# 13                                        Страна (ISO)
# 14                         Город (английское название)
# 15                                           ID страны
# 16                                           ID города
# 17                 Идентификатор пользователя на сайте
# 18                                      Тип соединения
# 19    Идентификатор целей, достигнутых за данный визит
# 20   Порядковые номера достижений цели с конкретным...
# 21   Время достижения каждой цели (в часовом поясе ...
# 22                                       Ценность цели
# 23                               Идентификатор заказов
# 24                                Идентификатор валюты
# 25                                    Источник трафика
# 26                                   Рекламная система
# 27                                    Переход с сайтов
# 28                                   Поисковая система
# 29                        Поисковая система (детально)
# 30                                     Cоциальная сеть
# 31                              Группа социальной сети
# 32                                             Реферер
# 33                             Кампания Яндекс.Директа
# 34                                   Группа объявлений
# 35                           Объявление Яндекс.Директа
# 36                    Название кампании Яндекс.Директа
# 37                          Название группы объявлений
# 38                  Название объявления Яндекс.Директа
# 39                           Условие показа объявления
# 40                                        Тип площадки
# 41                                            Площадка
# 42                       Тип условия показа объявления
# 43                                              Валюта
# 44                                          Метка from
# 45                                        UTM Campaign
# 46                                         UTM Content
# 47                                          UTM Medium
# 48                                          UTM Source
# 49                                            UTM Term
# 50                                         Openstat Ad
# 51                                   Openstat Campaign
# 52                                    Openstat Service
# 53                                     Openstat Source
# 54                                 Наличие метки GCLID
# 55                             GCLID последнего визита
# 56                                GCLID первого визита
# 57                   GCLID последнего значимого визита
# 58                                       Язык браузера
# 59                                     Страна браузера
# 60               Часовой пояс на компьютере посетителя
# 61   Тип устройства. Возможные значения: 1 — дескто...
# 62                            Производитель устройства
# 63                                   Модель устройства
# 64                          Группа операционных систем
# 65                     Операционная система (детально)
# 66                                             Браузер
# 67                                     Движок браузера
# 68                                      Наличие Cookie
# 69                                  Наличие JavaScript
# 70                                  Соотношение сторон
# 71                                       Глубина цвета
# 72                                   Ориентация экрана
# 73                                   Логическая ширина
# 74                                   Логическая высота
# 75                                   Физическая ширина
# 76                                   Физическая высота
# 77                                         Ширина окна
# 78                                         Высота окна
# 79                               Идентификатор покупки
# 80                                Дата и время покупки
# 81   Магазин или филиал, в котором произошла транза...
# 82                                    Полученный доход
# 83         Сумма всех налогов, связанных с транзакцией
# 84         Стоимость доставки, связанная с транзакцией
# 85   Промокод, ассоциированный со всей покупкой цел...
# 86                                              Валюта
# 87                        Количество товаров в покупке
# 88                               Идентификатор покупки
# 89                                Идентификатор товара
# 90                                     Название товара
# 91                                Производитель товара
# 92                Категория, к которой относится товар
# 93     Категория, к которой относится товар, уровень 1
# 94     Категория, к которой относится товар, уровень 2
# 95     Категория, к которой относится товар, уровень 3
# 96     Категория, к которой относится товар, уровень 4
# 97     Категория, к которой относится товар, уровень 5
# 98                                Разновидность товара
# 99                           Положение товара в списке
# 100                                        Цена товара
# 101                                      Валюта товара
# 102                 Промокод ассоциированный с товаром
# 103                                  Количество товара
# 104                             URL страницы с товаром
# 105                             Дата и время просмотра
# 106                Идентификатор просмотренного товара
# 107                     Название просмотренного товара
# 108                Производитель просмотренного товара
# 109  Категория, к которой относится просмотренный т...
# 110  Категория, к которой относится просмотренный т...
# 111  Категория, к которой относится просмотренный т...
# 112  Категория, к которой относится просмотренный т...
# 113  Категория, к которой относится просмотренный т...
# 114  Категория, к которой относится просмотренный т...
# 115                Разновидность просмотренного товара
# 116                         Цена просмотренного товара
# 117                                  Валюта для товара
# 118   Промокод ассоциированный с просмотренным товаром
# 119                     Длительность звонка в секундах
# 120            Длительность ожидания звонка в секундах
# 121                                 Пропущен ли звонок
# 122                                 Произвольная метка
# 123                                Первичный ли звонок
# 124  URL, с которого был звонок (ассоциированная с ...
# 125                            Параметры визита, ур. 1
# 126                            Параметры визита, ур. 2
# 127                            Параметры визита, ур. 3
# 128                            Параметры визита, ур. 4
# 129                            Параметры визита, ур. 5
# 130                            Параметры визита, ур. 6
# 131                           Параметры визита, ур. 7
# 132                            Параметры визита, ур. 8
# 133                            Параметры визита, ур. 9
# 134                           Параметры визита, ур. 10

# %%
# список индексов необходимых полей
# если список пустой, будут взяты все столбцы
# для получения конкретных столбцов нужно указать их в списке, через запятую

num_visits = [] # [0,1,2,3,6,7,8,9,10,11,13,14,17,18,27,28,30,61,62,65,66]
str_visits = columns(vis, num_visits)
str_visits

# %% [markdown]
# #### hits

# %%
from io import BytesIO

spreadsheet_id = '1UW4VJI1BXy8q_T3R1dfbz3vKO9apyoJmlWycelHvUVU'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
hits = pd.read_csv(BytesIO(r.content))

hits.columns = hits.columns.str.replace(' ','')
hits['Поле'] = hits['Поле'].str.replace(' ','')

# %% [raw]
# # посмотреть список полей с описанием
# print_full(hits)

# %%
# список индексов необходимых полей
# если список пустой, будут взяты все столбцы
# для получения конкретных столбцов нужно указать их в списке, через запятую

num_hits = [] # [0,1,2,3,6,7,8,9,10,11,13,14,17,18,27,28,30,61,62,65,66]
str_hits = columns(hits, num_hits)

# %% [markdown]
# ## Получаем Id запросов, существующих на сервере Logs API

# %%
# получаем все идентификаторы запросов на сервере
get_all_id_requests(counterId, token)

# %% [markdown]
# ## Очищаем список запросов на сервере Logs API

# %%
# удаляем запросы на сервере Logs API (если сущетсвуют)
# опционально
clean = clean_all_request(counterId, token)
clean

# %% [markdown]
# ## Создаем новый запрос 'visits' или 'hits'

# %%
# создаем новый запрос логов/// не работает Major-версия браузера	Minor-версия браузера

# dt1, dt2  - начальная и конечная (не может быть текущим днем) даты формата 'YYYY-MM-DD'
# source    - источинк данных данных для запроса ('hits' или 'visits')
dt1, dt2 = '2022-06-01', '2022-07-25'
source = 'visits'

col = str_visits if source == 'visits' else str_hits
query1 = make_post_request(source=source, token=token, counterId=counterId, dt1=dt1, dt2=dt2, col=col)

# %% [markdown]
# ## Проверяем статус нужного запроса по requestId

# %%
# проверяем готовность запроса к скачиванию
check1 = check_request_status(counterId, token, requestId='28231771')
# статус дложен быть 'processed'!
check1

# %% [markdown]
# ## Записываем файл в формате DataFrame пакета pandas

# %%
df = request_to_dataframe(counterId=counterId, token=token, requestId='28231771')
df.head()

# %% [markdown]
# ## Записываем в файл формата csv, если требуется открыть в Excel
# Записывается в ту же папку, где находится данный блокнот

# %%
# записываем DataFrame в csv
df.to_csv(f'{source}_{df['date'].min()}_{df['date'].max()}.csv', sep='\t')#, encoding='cp1251')
